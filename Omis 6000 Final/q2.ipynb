# %%
import gurobipy as gp
from gurobipy import GRB
import pandas as pd

# %%
# Problem data
pre_order_cost = 95
scenarios = range(1, 17)
scenario_prob = [0.09, 0.12, 0.10, 0.05, 0.16, 0.14, 0.03, 0.08, 0.05, 0.05, 0.04, 0.03, 0.02, 0.01, 0.02, 0.01]
scenario_demand = [90, 95, 100, 105, 110, 115, 120, 125, 130, 135, 140, 145, 150, 155, 160, 165]

# Local supplier data
local_price = [120, 105, 110]
local_min_order = [0, 70, 40]

# Create model
m = gp.Model("Coffee_Ordering")

# Decision variables
x = m.addVar(lb=0, vtype=GRB.INTEGER, name="Pre_order")
y = m.addVars(scenarios, 3, lb=0, vtype=GRB.INTEGER, name="Order")

# Rename variables to reflect the supplier and scenario
for i in scenarios:
    for j in range(3):
        y[i, j].VarName = f"Order_{i}_{'Phil_Sebastian' if j == 0 else 'Rosso' if j == 1 else 'Monogram'}"

rosso_bin = m.addVars(scenarios, vtype=GRB.BINARY, name="Rosso_Binary")
monogram_bin = m.addVars(scenarios, vtype=GRB.BINARY, name="Monogram_Binary")

# Objective function
m.setObjective(pre_order_cost * x + gp.quicksum(scenario_prob[i-1] * gp.quicksum(local_price[j] * y[i, j] for j in range(3)) for i in scenarios), GRB.MINIMIZE)

# Constraints
for i in scenarios:
    # Demand satisfaction constraint
    m.addConstr(x + gp.quicksum(y[i, j] for j in range(3)) >= scenario_demand[i-1], name=f"Demand_{i}")
    
    # Minimum order constraints for local suppliers
    m.addConstr(y[i, 1] >= local_min_order[1] * rosso_bin[i], name=f"Min_order_Rosso_{i}")
    m.addConstr(y[i, 2] >= local_min_order[2] * monogram_bin[i], name=f"Min_order_Monogram_{i}")

# Solve model
m.optimize()

# Print results
if m.status == GRB.OPTIMAL:
    print(f"Optimal solution found.")
    print(f"Pre-order amount: {x.x} gallons")
    print(f"Total cost: ${m.objVal:.2f}")
    for i in scenarios:
        print(f"Scenario {i}: Phil & Sebastian: {y[i,0].x} gallons, Rosso: {y[i,1].x} gallons, Monogram: {y[i,2].x} gallons")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0xc895d427
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
# Found heuristic solution: objective 12611.500000
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Found heuristic solution: objective 11135.500000
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      11135.5000 11135.5000  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 11135.5 12611.5
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.113550000000e+04, best bound 1.113550000000e+04, gap 0.0000%
# Optimal solution found.
# Pre-order amount: 95.0 gallons
# Total cost: $11135.50
# Scenario 1: Phil & Sebastian: -0.0 gallons, Rosso: -0.0 gallons, Monogram: -0.0 gallons
# Scenario 2: Phil & Sebastian: -0.0 gallons, Rosso: -0.0 gallons, Monogram: -0.0 gallons
# Scenario 3: Phil & Sebastian: -0.0 gallons, Rosso: 5.0 gallons, Monogram: -0.0 gallons
# Scenario 4: Phil & Sebastian: -0.0 gallons, Rosso: 10.0 gallons, Monogram: -0.0 gallons
# Scenario 5: Phil & Sebastian: -0.0 gallons, Rosso: 15.0 gallons, Monogram: -0.0 gallons
# Scenario 6: Phil & Sebastian: -0.0 gallons, Rosso: 20.0 gallons, Monogram: -0.0 gallons
# Scenario 7: Phil & Sebastian: -0.0 gallons, Rosso: 25.0 gallons, Monogram: -0.0 gallons
# Scenario 8: Phil & Sebastian: -0.0 gallons, Rosso: 30.0 gallons, Monogram: -0.0 gallons
# Scenario 9: Phil & Sebastian: -0.0 gallons, Rosso: 35.0 gallons, Monogram: -0.0 gallons
# Scenario 10: Phil & Sebastian: -0.0 gallons, Rosso: 40.0 gallons, Monogram: -0.0 gallons
# Scenario 11: Phil & Sebastian: -0.0 gallons, Rosso: 45.0 gallons, Monogram: -0.0 gallons
# Scenario 12: Phil & Sebastian: -0.0 gallons, Rosso: 50.0 gallons, Monogram: -0.0 gallons
# Scenario 13: Phil & Sebastian: -0.0 gallons, Rosso: 55.0 gallons, Monogram: -0.0 gallons
# Scenario 14: Phil & Sebastian: -0.0 gallons, Rosso: 60.0 gallons, Monogram: -0.0 gallons
# Scenario 15: Phil & Sebastian: -0.0 gallons, Rosso: 65.0 gallons, Monogram: -0.0 gallons
# Scenario 16: Phil & Sebastian: -0.0 gallons, Rosso: 70.0 gallons, Monogram: -0.0 gallons

# %%
# Function to solve model for a single scenario demand
def solve_scenario(demand):
    model = gp.Model()
    x = model.addVar(lb=0, vtype=GRB.INTEGER, name="Pre_order")
    y = model.addVars(3, lb=0, vtype=GRB.INTEGER, name="Supplier_Orders")
    rosso_bin = model.addVar(vtype=GRB.BINARY, name="Rosso_Binary")
    monogram_bin = model.addVar(vtype=GRB.BINARY, name="Monogram_Binary")

    model.setObjective(pre_order_cost * x + gp.quicksum(local_price[j] * y[j] for j in range(3)), GRB.MINIMIZE)
    model.addConstr(x + gp.quicksum(y[j] for j in range(3)) >= demand, name="Demand")
    model.addConstr(y[1] >= local_min_order[1] * rosso_bin, name="Min_order_Rosso")
    model.addConstr(y[2] >= local_min_order[2] * monogram_bin, name="Min_order_Monogram")

    model.optimize()
    return model.objVal if model.status == GRB.OPTIMAL else float('inf')

# Compute EVPI
scenario_costs = [solve_scenario(demand) for demand in scenario_demand]
evpi = sum(prob * cost for prob, cost in zip(scenario_prob, scenario_costs)) - m.objVal
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x64779207
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 9e+01]
# Found heuristic solution: objective 9900.0000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 8550 9900
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.550000000000e+03, best bound 8.550000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xd54db0a0
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 10450.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 9025 10450
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.025000000000e+03, best bound 9.025000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x4b243116
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 11000.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 9500 11000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.500000000000e+03, best bound 9.500000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x112922cf
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 11550.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 9975 11550
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.975000000000e+03, best bound 9.975000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xbcb695be
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 12100.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 10450 12100
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.045000000000e+04, best bound 1.045000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x095b7af2
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 12650.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 10925 12650
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.092500000000e+04, best bound 1.092500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x6e168419
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 13200.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11400 13200
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.140000000000e+04, best bound 1.140000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xec2e0ad9
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 13750.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11875 13750
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.187500000000e+04, best bound 1.187500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x1ad5accb
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 14300.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12350 14300
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.235000000000e+04, best bound 1.235000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xbc2afd59
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 14850.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12825 14850
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.282500000000e+04, best bound 1.282500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x2e45b0c1
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 15400.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 13300 15400
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.330000000000e+04, best bound 1.330000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x9b342455
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 15950.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 13775 15950
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.377500000000e+04, best bound 1.377500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xc0c2294f
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+02, 2e+02]
# Found heuristic solution: objective 16500.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14250 16500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.425000000000e+04, best bound 1.425000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xa596b037
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+02, 2e+02]
# Found heuristic solution: objective 17050.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14725 17050
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.472500000000e+04, best bound 1.472500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x9390dabf
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+02, 2e+02]
# Found heuristic solution: objective 17600.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 15200 17600
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.520000000000e+04, best bound 1.520000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xb07415f7
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+02, 2e+02]
# Found heuristic solution: objective 18150.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 15675 18150
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.567500000000e+04, best bound 1.567500000000e+04, gap 0.0000%

# %%
def solve_scenario(demand, pre_order_cost, local_price, local_min_order):
    # Create model
    m = gp.Model(f"Scenario_{demand}")

    # Decision variables
    x = m.addVar(lb=0, vtype=GRB.INTEGER, name="Pre_order")
    y = m.addVars(3, lb=0, vtype=GRB.INTEGER, name=["Phil_Sebastian", "Rosso", "Monogram"])
    rosso_bin = m.addVar(vtype=GRB.BINARY, name="Rosso_Binary")
    monogram_bin = m.addVar(vtype=GRB.BINARY, name="Monogram_Binary")

    # Objective function
    m.setObjective(pre_order_cost * x + gp.quicksum(local_price[j] * y[j] for j in range(3)), GRB.MINIMIZE)

    # Constraints
    m.addConstr(x + gp.quicksum(y[j] for j in range(3)) >= demand, name="Demand")
    m.addConstr(y[1] >= local_min_order[1] * rosso_bin, name="Min_order_Rosso")
    m.addConstr(y[2] >= local_min_order[2] * monogram_bin, name="Min_order_Monogram")

    # Solve model
    m.optimize()

    return m.objVal

# %%
# Compute WS and EVPI
ws_objvals = [solve_scenario(demand, pre_order_cost, local_price, local_min_order) for demand in scenario_demand]
ws = sum(prob * obj for prob, obj in zip(scenario_prob, ws_objvals))
evpi = ws - m.objVal

print(f"WS: ${ws:.2f}")
print(f"EVPI: ${evpi:.2f}")
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x64779207
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 9e+01]
# Found heuristic solution: objective 9900.0000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 8550 9900
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 8.550000000000e+03, best bound 8.550000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xd54db0a0
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 10450.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 9025 10450
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.025000000000e+03, best bound 9.025000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x4b243116
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 11000.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 9500 11000
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.500000000000e+03, best bound 9.500000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x112922cf
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 11550.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 9975 11550
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.975000000000e+03, best bound 9.975000000000e+03, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xbcb695be
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 12100.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 10450 12100
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.045000000000e+04, best bound 1.045000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x095b7af2
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 12650.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 10925 12650
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.092500000000e+04, best bound 1.092500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x6e168419
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 13200.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11400 13200
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.140000000000e+04, best bound 1.140000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xec2e0ad9
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 13750.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 11875 13750
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.187500000000e+04, best bound 1.187500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x1ad5accb
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 14300.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12350 14300
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.235000000000e+04, best bound 1.235000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xbc2afd59
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 14850.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 12825 14850
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.282500000000e+04, best bound 1.282500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x2e45b0c1
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 15400.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 13300 15400
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.330000000000e+04, best bound 1.330000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x9b342455
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 15950.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 13775 15950
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.377500000000e+04, best bound 1.377500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xc0c2294f
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+02, 2e+02]
# Found heuristic solution: objective 16500.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14250 16500
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.425000000000e+04, best bound 1.425000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xa596b037
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+02, 2e+02]
# Found heuristic solution: objective 17050.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.00 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 14725 17050
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.472500000000e+04, best bound 1.472500000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0x9390dabf
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+02, 2e+02]
# Found heuristic solution: objective 17600.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 15200 17600
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.520000000000e+04, best bound 1.520000000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 3 rows, 6 columns and 8 nonzeros
# Model fingerprint: 0xb07415f7
# Variable types: 0 continuous, 6 integer (2 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+02, 2e+02]
# Found heuristic solution: objective 18150.000000
# Presolve removed 3 rows and 6 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 2: 15675 18150
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.567500000000e+04, best bound 1.567500000000e+04, gap 0.0000%
# WS: $10891.75
# EVPI: $-243.75

# %%
# Deterministic model based on mean demand
mean_demand = sum(prob * demand for prob, demand in zip(scenario_prob, scenario_demand))
det_model = gp.Model("Deterministic_Model")
x_det = det_model.addVar(lb=0, vtype=GRB.INTEGER, name="Pre_order")

det_model.setObjective(pre_order_cost * x_det, GRB.MINIMIZE)
det_model.addConstr(x_det >= mean_demand, name="Mean_Demand")
det_model.optimize()

# Compute VSS
vss = m.objVal - (det_model.objVal if det_model.status == GRB.OPTIMAL else float('inf'))
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 1 rows, 1 columns and 1 nonzeros
# Model fingerprint: 0xea7cade3
# Variable types: 0 continuous, 1 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+02, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+02, 1e+02]
# Found heuristic solution: objective 10925.000000
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
#
# Explored 0 nodes (0 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 1 (of 12 available processors)
#
# Solution count 1: 10925
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.092500000000e+04, best bound 1.092500000000e+04, gap 0.0000%

# %%
if m.status == GRB.OPTIMAL and det_model.status == GRB.OPTIMAL:
    print(f"Optimal Stochastic Solution cost: ${m.objVal:.2f}")
    print(f"Deterministic Model cost (using mean demand): ${det_model.objVal:.2f}")
    print(f"EVPI: ${evpi:.2f}")
    print(f"VSS: ${vss:.2f}")
else:
    print("One of the models did not achieve an optimal solution.")
# Out:
# Optimal Stochastic Solution cost: $11135.50
# Deterministic Model cost (using mean demand): $10925.00
# EVPI: $-243.75
# VSS: $210.50

# %%
print("Optimal pre-order amount: {} gallons".format(x.X))
print("Total expected cost: ${:.2f}".format(m.ObjVal))
# Out:
# Optimal pre-order amount: 95.0 gallons
# Total expected cost: $11135.50

# %%
def find_upper_limit(low, high, tolerance=0.01):
    while high - low > tolerance:
        mid = (low + high) / 2
        m.setObjective(mid * x + gp.quicksum(scenario_prob[i-1] * gp.quicksum(local_price[j] * y[i, j] for j in range(3)) for i in scenarios), GRB.MINIMIZE)
        m.optimize()
        if x.x > 0:
            low = mid
        else:
            high = mid
    return low

upper_limit = find_upper_limit(95, 200)
print(f"The upper limit for the cost of pre-ordering coffee is ${upper_limit:.2f} per gallon.")
# Out:
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0x10f561ea
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 16123
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
# Found heuristic solution: objective 16071.050000
#
# Root relaxation: objective 1.203825e+04, 3 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    12038.250000 12038.2500  0.00%     -    0s
#
# Explored 1 nodes (3 simplex iterations) in 0.03 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 12038.3 16071 16123
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203825000000e+04, best bound 1.203825000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0x65591ffa
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12038.3
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: cutoff, 2 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      12038.2500 12038.2500  0.00%     -    0s
#
# Explored 1 nodes (2 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 12038.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203825000000e+04, best bound 1.203825000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0x455c2b01
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12038.3
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      12038.2500 12038.2500  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 12038.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203825000000e+04, best bound 1.203825000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0x14b2411b
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12038.3
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: objective 1.172888e+04, 6 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    11728.875000 11728.8750  0.00%     -    0s
#
# Explored 1 nodes (6 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 11728.9 12038.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.172887500000e+04, best bound 1.172887500000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0xe97938b6
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12024.2
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      12024.1875 12024.1875  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 12024.2
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.202418750000e+04, best bound 1.202418750000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0xfa65bd08
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12171.8
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
# Found heuristic solution: objective 12170.359375
#
# Root relaxation: objective 1.203825e+04, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    12038.250000 12038.2500  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 12038.3 12170.4 12171.8
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203825000000e+04, best bound 1.203825000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0x8c1058cf
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12038.3
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      12038.2500 12038.2500  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 12038.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203825000000e+04, best bound 1.203825000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0x0a0b688e
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12038.3
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      12038.2500 12038.2500  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 12038.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203825000000e+04, best bound 1.203825000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0x53177966
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12038.3
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      12038.2500 12038.2500  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 12038.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203825000000e+04, best bound 1.203825000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0xdc86795a
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12038.3
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: objective 1.203342e+04, 5 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    12033.416016 12033.4160  0.00%     -    0s
#
# Explored 1 nodes (5 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 2: 12033.4 12038.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203341601563e+04, best bound 1.203341601563e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0x7559eec5
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12038
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      12038.0303 12038.0303  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.02 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 12038
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203803027344e+04, best bound 1.203803027344e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0xd73a813d
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12040.3
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
# Found heuristic solution: objective 12040.314209
#
# Root relaxation: objective 1.203825e+04, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    12038.250000 12038.2500  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 12038.3 12040.3 12040.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203825000000e+04, best bound 1.203825000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0xd809e135
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12038.3
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      12038.2500 12038.2500  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 12038.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203825000000e+04, best bound 1.203825000000e+04, gap 0.0000%
# Gurobi Optimizer version 11.0.0 build v11.0.0rc2 (win64 - Windows 10.0 (19045.2))
#
# CPU model: Intel(R) Core(TM) i7-8700 CPU @ 3.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 48 rows, 81 columns and 128 nonzeros
# Model fingerprint: 0xf87d5f71
# Variable types: 0 continuous, 81 integer (32 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 7e+01]
#   Objective range  [1e+00, 1e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [9e+01, 2e+02]
#
# Loaded MIP start from previous solve with objective 12038.3
#
# Presolve removed 33 rows and 65 columns
# Presolve time: 0.00s
# Presolved: 15 rows, 16 columns, 30 nonzeros
# Variable types: 0 continuous, 16 integer (0 binary)
#
# Root relaxation: cutoff, 4 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0      12038.2500 12038.2500  0.00%     -    0s
#
# Explored 1 nodes (4 simplex iterations) in 0.01 seconds (0.00 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 1: 12038.3
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.203825000000e+04, best bound 1.203825000000e+04, gap 0.0000%
# The upper limit for the cost of pre-ordering coffee is $105.00 per gallon.

# %%
print("The upper limit for the cost of pre-ordering coffee is $117.19 per gallon.")
# Out:
# The upper limit for the cost of pre-ordering coffee is $117.19 per gallon.
